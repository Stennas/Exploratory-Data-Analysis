# %%
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#      User.ID  Age  Gender    Country Device.Type  Daily.Screen.Time  \
# 0          1   54  Female    Germany      Tablet                5.0
# 1          2   44   Other  Australia      Laptop                4.6
# 2          3   30  Female        USA       Phone                3.5
# 3          4   58  Female     Canada      Laptop               10.0
# 4          5   23  Female         UK      Laptop                7.1
# ..       ...  ...     ...        ...         ...                ...
# 995      996   39  Female      India      Laptop                5.7
# 996      997   24  Female      India       Phone                9.9
# 997      998   18  Female      India      Laptop                3.9
# 998      999   46  Female    Germany       Phone                4.4
# 999     1000   55    Male  Australia       Phone                8.8
#
#      Social.Media.Hours  Work.Screen.Hours  Gaming.Hours  Sleep.Hours  \
# 0                   1.9                6.0           0.9          6.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   User.ID                1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Country                1000 non-null   object
#  4   Device.Type            1000 non-null   object
#  5   Daily.Screen.Time      1000 non-null   float64
#  6   Social.Media.Hours     1000 non-null   float64
#  7   Work.Screen.Hours      1000 non-null   float64
#  8   Gaming.Hours           1000 non-null   float64
#  9   Sleep.Hours            1000 non-null   float64
#  10  Sleep.Quality          1000 non-null   int64
#  11  Stress.Level           1000 non-null   int64
#  12  Physical.Activity.Min  1000 non-null   int64
#  13  Productivity.Score     1000 non-null   int64
# ...
